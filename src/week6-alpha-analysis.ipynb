# %%
import numpy as np
import pandas as pd
from pathmgmt import pathmgmt as myPath
import os

# %%
# Combine all alphas
def get_stat():
    res = pd.DataFrame()
    for folderName in os.listdir(myPath.PLOT_DIR):
        if 'zz9999' not in folderName or 'Vol' not in folderName:
            continue
        # print(folderName)
        folder = myPath.PLOT_DIR/folderName/'statistics'
        for fileName in os.listdir(folder):
            # print(fileName)
            file = folder/fileName
            df = pd.read_csv(file)
            df.index = [f'{folderName};{fileName[:-15]}']
            # print(df)
            if res.empty:
                res = df
            else:
                res = pd.concat([res, df])
    return res

# %%
stats = get_stat()

# %%
stats.describe()
# Out:
#        Annualized Return  Annualized Excess Return          IR  IR long only  \
# count         372.000000                372.000000  366.000000    372.000000
# mean            0.116773                 -0.102999    1.867542     -0.795522
# std             0.085956                  0.040702    1.035233      0.309199
# min            -0.019162                 -0.221433   -1.096069     -1.615433
# 25%             0.039429                 -0.122903    1.400462     -0.953671
# 50%             0.118469                 -0.096284    1.868106     -0.764785
# 75%             0.178668                 -0.078087    2.463512     -0.579251
# max             0.409374                  0.003246    6.098590      0.024830
#
#                IC  Max Drawdown  Max Drawdown long only  daily Turnover
# count  366.000000    372.000000              372.000000      372.000000
# mean     0.006638      0.059086                0.376955        0.147417
# std      0.004462      0.029368                0.101609        0.180126
# min     -0.001334     -0.000000                0.191635        0.000000
# 25%      0.003554      0.039116                0.299868        0.038376
# 50%      0.006077      0.055874                0.363979        0.082344
# 75%      0.008744      0.084306                0.460906        0.188414
# max      0.026110      0.112945                0.667850        1.370488

# %%
good_alphas = list(stats.loc[stats.IR > 3].index)

# %%
len(good_alphas)
# Out:
# 37

# %%
# combine daily pnl
def get_pnl():
    res = pd.DataFrame()
    for folderName in os.listdir(myPath.PLOT_DIR):
        if 'zz9999' not in folderName and 'Vol' not in folderName:
            continue
        # print(folderName)
        folder = myPath.PLOT_DIR/folderName/'PnL_results'
        for fileName in os.listdir(folder):
            file = folder/fileName
            df = pd.read_csv(file)
            # df = df.set_index('time')
            # df = df['pnl']
            df = df[['time', 'pnl']]
            df.rename(
                columns={'pnl': f'{folderName};{fileName[:-13]}'}, inplace=True)
            if res.empty:
                res = df
            else:
                res = res.merge(df, on='time', how='outer')
    res = res.set_index('time').sort_index()
    return res

# %%
pnls = get_pnl()

# %%
corr = pnls[good_alphas].corr()

# %%
from itertools import combinations
import random
res = []
num = 4
good_candidates = list(
    ((corr.mask(np.eye(len(corr), dtype=bool)).abs() < 0.6).sum() > num).index)
random.shuffle(good_candidates)
for cols in combinations(good_candidates, num):
    corr_small = corr.loc[cols, cols]
    if (~(corr_small.mask(np.eye(len(corr_small), dtype=bool)).abs() > 0.6).any()).sum() == num:
        res.append(corr_small)

# %%
max_IR = float('-inf')
max_idx = -1
for i in range(len(res)):
    total_IR = np.sum([(stats.loc[stats.index==name].IR) for name in res[i].index])
    if total_IR > max_IR:
        max_IR = total_IR
        max_idx = i

# %%
res[max_idx]
# Out:
#                                                     alpha.YaoVol002-60days-zz9999;20180101-20201231-Rank-Industry-holding3days  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...                                           1.000000
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...                                           0.366266
# alpha.YaoVol005-20days-zz9999;20180101-20201231...                                           0.253826
# alpha.YaoVol007-10days-zz9999;20180101-20201231...                                           0.191765
#
#                                                     alpha.YaoVol006-3days-zz9999;20180101-20201231-Rank-Industry-holding1days  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...                                           0.366266
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...                                           1.000000
# alpha.YaoVol005-20days-zz9999;20180101-20201231...                                           0.461368
# alpha.YaoVol007-10days-zz9999;20180101-20201231...                                           0.166075
#
#                                                     alpha.YaoVol005-20days-zz9999;20180101-20201231-Rank-Industry-holding60days  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...                                           0.253826
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...                                           0.461368
# alpha.YaoVol005-20days-zz9999;20180101-20201231...                                           1.000000
# alpha.YaoVol007-10days-zz9999;20180101-20201231...                                           0.071407
#
#                                                     alpha.YaoVol007-10days-zz9999;20180101-20201231-Rank-Industry-holding1days
# alpha.YaoVol002-60days-zz9999;20180101-20201231...                                           0.191765
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...                                           0.166075
# alpha.YaoVol005-20days-zz9999;20180101-20201231...                                           0.071407
# alpha.YaoVol007-10days-zz9999;20180101-20201231...                                           1.000000

# %%
stats.loc[stats.index.isin(res[max_idx].index)]
# Out:
#                                                     Annualized Return  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...           0.147306
# alpha.YaoVol005-20days-zz9999;20180101-20201231...           0.023955
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...           0.382751
# alpha.YaoVol007-10days-zz9999;20180101-20201231...           0.098923
#
#                                                     Annualized Excess Return  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...                 -0.104327
# alpha.YaoVol005-20days-zz9999;20180101-20201231...                 -0.108468
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...                 -0.023038
# alpha.YaoVol007-10days-zz9999;20180101-20201231...                 -0.102236
#
#                                                           IR  IR long only  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...  3.240497     -0.772919
# alpha.YaoVol005-20days-zz9999;20180101-20201231...  3.054662     -0.680418
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...  6.098590     -0.166761
# alpha.YaoVol007-10days-zz9999;20180101-20201231...  3.547320     -0.738922
#
#                                                           IC  Max Drawdown  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...  0.010048      0.042189
# alpha.YaoVol005-20days-zz9999;20180101-20201231...  0.005021      0.008389
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...  0.024658      0.036727
# alpha.YaoVol007-10days-zz9999;20180101-20201231...  0.007169      0.022099
#
#                                                     Max Drawdown long only  \
# alpha.YaoVol002-60days-zz9999;20180101-20201231...                0.285442
# alpha.YaoVol005-20days-zz9999;20180101-20201231...                0.462555
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...                0.191635
# alpha.YaoVol007-10days-zz9999;20180101-20201231...                0.405913
#
#                                                     daily Turnover
# alpha.YaoVol002-60days-zz9999;20180101-20201231...        0.078172
# alpha.YaoVol005-20days-zz9999;20180101-20201231...        0.021801
# alpha.YaoVol006-3days-zz9999;20180101-20201231-...        0.770609
# alpha.YaoVol007-10days-zz9999;20180101-20201231...        0.565616
